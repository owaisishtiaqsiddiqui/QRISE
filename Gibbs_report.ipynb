# %% [markdown]
# Transverse Field Ising Model Hamiltonian used as the model of the system we are exploring. The number of sites and constants J and h are all adjustable.

# %% [markdown]
# ![title](img/Hamiltonian.png)

# %% [markdown]
# ![Hamiltonian.webp](attachment:Hamiltonian.webp)

# %% [markdown]
# Ansatz used to measure the Hamiltonian against with parameters used for variational minimization

# %% [markdown]
# Cost function equation used in minimization method. Minimizing the equation with respect to theta leads to the Gibbs Free Energy of the measured Hamiltonian. H is the Hamiltonian and rho is the state density matrix. From Paper https://arxiv.org/pdf/2005.08797.pdf

# %% [markdown]
# ![title](img/Truncated_Free_Energy.png)

# %% [markdown]
# ![Truncated_Free_Energy.webp](attachment:Truncated_Free_Energy.webp)

# %% [markdown]
# Algirithm for computing the Gibbs Free Energy using the variational minimizaiton method and a second order trunction of the energy approximation. From Paper https://arxiv.org/pdf/2005.08797.pdf

# %% [markdown]
# ![title](img/Algorithm.png)

# %% [markdown]
# ![Algorithm.webp](attachment:Algorithm.webp)

# %% [markdown]
# Quantum Circuit for calculating Tr(rho^3) using a mid-circuit reset. This is an extension of the SWAP test for caclulating states overlap. The measured qubit indicates the probablity of the states in the circuit overlapping. From Paper https://arxiv.org/pdf/2005.08797.pdf

# %% [markdown]
# ![title](img/Circuit.png)

# %% [markdown]
# ![Circuit.webp](attachment:Circuit.webp)

# %% [markdown]
# Schematic for the optimization and energy calculation. From Paper https://arxiv.org/pdf/2005.08797.pdf

# %% [markdown]
# ![title](img/Method.png)

# %% [markdown]
# ![Method.webp](attachment:Method.webp)

# %% [markdown]
# Quasi-Probabilistic Readout Correctoin of Mid-Circuit Measurments method schematic. Can help reduce the probability of measurment readout error from ~23% to ~18% using mid-circuit measurements and state reset. From Paper https://arxiv.org/pdf/2312.14139.pdf

# %% [markdown]
# ![title](img/QPRC_Mid.png)

# %% [markdown]
# ![QPRC_Mid.webp](attachment:QPRC_Mid.webp)
